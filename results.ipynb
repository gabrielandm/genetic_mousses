# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

sns.set_style("whitegrid")

results = pd.read_csv(r"C:\Users\USER\Git\genetic_mousses\results.csv")
results_complete = results[results['total_value'] == 3176]
time_avarage = results_complete['processing_time'].sum() / len(results_complete.index)
success_rate = (len(results_complete.index) * 100) / len(results.index)

print(f'Number of best values: {len(results_complete.index)}')
print(f'Success rate: {success_rate}%')
print(f'Processing time avarage: {time_avarage} seconds')
# Out:
# Number of best values: 598
# Success rate: 99.66666666666667%
# Processing time avarage: 0.09495492762945164 seconds

# %%
sns.scatterplot(
    data=results,
    x='generation_number',
    y='processing_time',
    hue='total_value',
)
# Out:
# <AxesSubplot:xlabel='generation_number', ylabel='processing_time'>

# %%
sns.stripplot(
    data=results,
    x='total_value',
    y='generation_number',
)
# Out:
# <AxesSubplot:xlabel='total_value', ylabel='generation_number'>
